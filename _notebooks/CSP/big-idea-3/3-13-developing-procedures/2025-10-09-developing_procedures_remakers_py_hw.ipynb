# %% [raw]
# ---
# toc: true
# layout: post
# categories: [Python]
# title: Remakers - 3.13 Developing Procedures Python Hacks
# description: "Apply your skills to basic procedure development in Javascript."
# permalink: /python/developing-procedures/remakers-hw
# author: Krishna Visvanath, Sloane Sommers
# ---

# %% [markdown]
# ### Q1 (Easy)
# Which of these procedures is named well, provide a **short** explanation of justification

# %%
def mix_ingredients(): #This procedure is named the best since it clearly gives a summary of the procedure's purpose and doesn't just give a vague idea like "do it"

def do_it():

def make_move():

# %% [markdown]
# **Explanation Here:**
# __ is right because..

# %% [markdown]
# ### Q2 (Medium)
# Finish the code to have a correctly named procedure

# %%
def make_left_turn():
    move_forward()
    rotate_90()
    move_forward_again()

##Todo: add corresponding procedure definitions
##here- replace this line with your code
def move_forward():
    print("Moving forward.")

##here- replace this line with your code
def rotate_90():
    print("Turning left")

##here- replace this line with your code
def move_forward_again():
    print("Moving forward again to complete left turn.")

# Run the procedure
if __name__ == '__main__':
    make_left_turn()
# Out:
# Moving forward.
# Turning left
# Moving forward again to complete left turn.

# %% [markdown]
# ### Q3 (Hard)
# Write code to fulfill the requirements
# Doing a dance! 🕺💃
# Must have
# 1. A shimmy left procedure
# - Print `super cool left slide`
# 2. A shimmy right procedure, print `even cooler right slide`
# 3. Doing a bow to the crowd, print `Great dance!`, `the audience claps at your bow!`

# %%
##Code away!
def perform_dance():
    left_procedure()
    right_procedure()
    finishing_bow()

def left_procedure():
    print("super super cool left slide")
def right_procedure():
    print("coolest right slide")
def finishing_bow():
    print("Great dance! The audience are happy")

if __name__ == '__main__':
    perform_dance()
# Out:
# super super cool left slide
# coolest right slide
# Great dance! The audience are happy
